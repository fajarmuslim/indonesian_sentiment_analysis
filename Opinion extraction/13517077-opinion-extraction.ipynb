# %%
import numpy as np
import pandas as pd
import math

# %%
# !git clone https://github.com/fajarmuslim/indonesian_sentiment_analysis.git
# Out:
# Cloning into 'indonesian_sentiment_analysis'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 33 (delta 16), reused 20 (delta 7), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %%
# !cd indonesian_sentiment_analysis && ls
# Out:
# LICENSE  README.md  aspect  data_sentences.csv	train_sentiment.txt

# %%
def get_review_tokens(filename):
    idx, raw, formalized = [], [], []
    with open(filename, encoding='utf-8') as f:
        i = 0
        for line in f:
            line = line.rstrip()
            if line:
                raw_token, formalized_token = line.split('\t')
                raw.append(raw_token)
                formalized.append(formalized_token)
                idx.append(i)
            else :
                i = i+1

    return idx, raw, formalized

# %%
idx, raw, formalized = get_review_tokens("./indonesian_sentiment_analysis/train_sentiment.txt")

# %%
def construct_dataset(idx, raw, formalized):
  new_data = {'sentence_idx':idx, 'word':raw, 'label':formalized}
  df = pd.DataFrame(new_data)
  return df

# %%
data = construct_dataset(idx, raw, formalized)
data.head(20)
# Out:
#     sentence_idx       word        label
# 0              0      kamar            O
# 1              0       saya            O
# 2              0        ada            O
# 3              0    kendala            O
# 4              0         di            O
# 5              0         ac     B-ASPECT
# 6              0      tidak  B-SENTIMENT
# 7              0  berfungsi  I-SENTIMENT
# 8              0    optimal  I-SENTIMENT
# 9              0          .            O
# 10             0        dan            O
# 11             0       juga            O
# 12             0       wifi     B-ASPECT
# 13             0    koneksi     I-ASPECT
# 14             0     kurang  B-SENTIMENT
# 15             0     stabil  I-SENTIMENT
# 16             0          .            O
# 17             1  tempatnya     B-ASPECT
# 18             1      bagus  B-SENTIMENT
# 19             1          .            O

# %%
print(data.shape)
# Out:
# (63105, 3)

# %%
#clean data
for i in range (len(data)):
    if(data['label'][i]=="B-ASPECT" or data['label'][i]=="I-ASPECT"):
        data['label'][i] = 'O'

data = data[data.word != '.']
data = data[data.word != ',']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data.head(20)
# Out:
#     sentence_idx       word        label
# 0              0      kamar            O
# 1              0       saya            O
# 2              0        ada            O
# 3              0    kendala            O
# 4              0         di            O
# 5              0         ac            O
# 6              0      tidak  B-SENTIMENT
# 7              0  berfungsi  I-SENTIMENT
# 8              0    optimal  I-SENTIMENT
# 10             0        dan            O
# 11             0       juga            O
# 12             0       wifi            O
# 13             0    koneksi            O
# 14             0     kurang  B-SENTIMENT
# 15             0     stabil  I-SENTIMENT
# 17             1  tempatnya            O
# 18             1      bagus  B-SENTIMENT
# 20             1      kolam            O
# 21             1  renangnya            O
# 22             1     bersih  B-SENTIMENT

# %%
data['label'].value_counts()
# Out:
# O              38476
# B-SENTIMENT     9646
# I-SENTIMENT     4265
# Name: label, dtype: int64

# %%
class SentenceGetter(object):
    
    def __init__(self, dataset):
        self.n_sent = 1
        self.dataset = dataset
        self.empty = False
        agg_func = lambda s: [(w, t) for w,t in zip(s["word"].values.tolist(),
                                                        s["label"].values.tolist())]
        self.grouped = self.dataset.groupby("sentence_idx").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None
          
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
len(sentences)
# Out:
# 4000

# %%
from math import nan

words = list(set(data["word"].values))
n_words = len(words)

tags = []
for tag in set(data["label"].values):
    if tag is nan or isinstance(tag, float):
        tags.append('unk')
    else:
        tags.append(tag)
n_tags = len(tags)

# %%
from future.utils import iteritems

word2idx = {w: i for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
idx2tag = {v: k for k, v in iteritems(tag2idx)}

# %%
tag2idx
# Out:
# {'B-SENTIMENT': 0, 'I-SENTIMENT': 1, 'O': 2}

# %%
idx2tag
# Out:
# {0: 'B-SENTIMENT', 1: 'I-SENTIMENT', 2: 'O'}

# %%
percentage_split = 0.1

# %%
sentences_train = sentences[:len(sentences)-int(len(sentences)*percentage_split)]
sentences_validation = sentences_train[len(sentences_train)-int(len(sentences_train)*percentage_split):]
sentences_test = sentences[len(sentences)-int(len(sentences)*percentage_split):]

# %%
sentences_train[1]
# Out:
# [('tempatnya', 'O'),
#  ('bagus', 'B-SENTIMENT'),
#  ('kolam', 'O'),
#  ('renangnya', 'O'),
#  ('bersih', 'B-SENTIMENT')]

# %%
len(sentences_test)
# Out:
# 400

# %%
maxlen = max([len(s) for s in sentences])
print("maxlen", maxlen)
# Out:
# maxlen 103

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train = [[word2idx[w[0]] for w in s] for s in sentences_train]
X_train = pad_sequences(maxlen=maxlen, sequences=X_train, padding="post",value=n_words - 1)

X_test = [[word2idx[w[0]] for w in s] for s in sentences_test]
X_test = pad_sequences(maxlen=maxlen, sequences=X_test, padding="post",value=n_words - 1)

X_validation = [[word2idx[w[0]] for w in s] for s in sentences_validation]
X_validation = pad_sequences(maxlen=maxlen, sequences=X_validation, padding="post",value=n_words - 1)

y_train = [[tag2idx[w[1]] for w in s] for s in sentences_train]
y_train = pad_sequences(maxlen=maxlen, sequences=y_train, padding="post", value=tag2idx["O"])
y_train = [to_categorical(i, num_classes=n_tags) for i in y_train]

y_test = [[tag2idx[w[1]] for w in s] for s in sentences_test]
y_test = pad_sequences(maxlen=maxlen, sequences=y_test, padding="post", value=tag2idx["O"])
y_test = [to_categorical(i, num_classes=n_tags) for i in y_test]

y_validation = [[tag2idx[w[1]] for w in s] for s in sentences_validation]
y_validation = pad_sequences(maxlen=maxlen, sequences=y_validation, padding="post", value=tag2idx["O"])
y_validation = [to_categorical(i, num_classes=n_tags) for i in y_validation]

# %%
X_train.shape
# Out:
# (3600, 103)

# %%
X_test.shape
# Out:
# (400, 103)

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-xmumjhzj
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-xmumjhzj
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (2.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (5.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.17.4)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.3.3)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras->keras-contrib==2.0.8) (1.13.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101065 sha256=9d2bc6484e79687841006b769814a8a7f67f52883a5c6494fae8367b68da37d1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_b5viacu/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %% [markdown]
# ## Model 1

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF

input = Input(shape=(maxlen,))
word_embedding_size = 150

# Embedding Layer
model = Embedding(input_dim=n_words, output_dim=word_embedding_size, input_length=maxlen)(input)

# BI-LSTM Layer
model = Bidirectional(LSTM(units=word_embedding_size, 
                           return_sequences=True, 
                           dropout=0.5, 
                           recurrent_dropout=0.5, 
                           kernel_initializer=k.initializers.he_normal()))(model)
model = LSTM(units=word_embedding_size * 2, 
             return_sequences=True, 
             dropout=0.5, 
             recurrent_dropout=0.5, 
             kernel_initializer=k.initializers.he_normal())(model)

# TimeDistributed Layer
model = TimeDistributed(Dense(n_tags, activation="relu"))(model)  

# CRF Layer
crf = CRF(n_tags)

out = crf(model)  # output
model = Model(input, out)

# %%
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

# Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])

model.summary()

# Saving the best model only
filepath="opinion-model-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=256, epochs=20, validation_split=0.1, verbose=1, callbacks=callbacks_list)
# history = model.fit(X_train, np.array(y_train), batch_size=256, epochs=20, validation_split=0.1, verbose=1)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 103)               0
# _________________________________________________________________
# embedding_17 (Embedding)     (None, 103, 150)          695400
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 103, 300)          361200
# _________________________________________________________________
# lstm_43 (LSTM)               (None, 103, 300)          721200
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 103, 3)            903
# _________________________________________________________________
# crf_16 (CRF)                 (None, 103, 3)            27
# =================================================================
# Total params: 1,778,730
# Trainable params: 1,778,730
# Non-trainable params: 0
# _________________________________________________________________
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3240 samples, validate on 360 samples
# Epoch 1/20
# 3240/3240 [==============================] - 10s 3ms/step - loss: 0.3392 - crf_viterbi_accuracy: 0.9349 - accuracy: 0.0235 - val_loss: 0.1106 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00001: val_accuracy improved from -inf to 0.96745, saving model to opinion-model-0.97.hdf5
# Epoch 2/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.1268 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.1134 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00002: val_accuracy did not improve from 0.96745
# Epoch 3/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.1139 - crf_viterbi_accuracy: 0.9657 - accuracy: 0.0235 - val_loss: 0.1049 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00003: val_accuracy did not improve from 0.96745
# Epoch 4/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.1089 - crf_viterbi_accuracy: 0.9659 - accuracy: 0.0235 - val_loss: 0.1000 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00004: val_accuracy did not improve from 0.96745
# Epoch 5/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.1037 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0962 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00005: val_accuracy did not improve from 0.96745
# Epoch 6/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.1001 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0940 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00006: val_accuracy did not improve from 0.96745
# Epoch 7/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0980 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0924 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00007: val_accuracy did not improve from 0.96745
# Epoch 8/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.0962 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0912 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00008: val_accuracy did not improve from 0.96745
# Epoch 9/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.0948 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0900 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00009: val_accuracy did not improve from 0.96745
# Epoch 10/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.0933 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0889 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00010: val_accuracy did not improve from 0.96745
# Epoch 11/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0919 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0876 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00011: val_accuracy did not improve from 0.96745
# Epoch 12/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0904 - crf_viterbi_accuracy: 0.9659 - accuracy: 0.0235 - val_loss: 0.0861 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00012: val_accuracy did not improve from 0.96745
# Epoch 13/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.0888 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0843 - val_crf_viterbi_accuracy: 0.9685 - val_accuracy: 0.9675
#
# Epoch 00013: val_accuracy improved from 0.96745 to 0.96753, saving model to opinion-model-0.97.hdf5
# Epoch 14/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.0868 - crf_viterbi_accuracy: 0.9659 - accuracy: 0.0235 - val_loss: 0.0823 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9675
#
# Epoch 00014: val_accuracy did not improve from 0.96753
# Epoch 15/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0846 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0801 - val_crf_viterbi_accuracy: 0.9685 - val_accuracy: 0.9675
#
# Epoch 00015: val_accuracy did not improve from 0.96753
# Epoch 16/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0825 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.0775 - val_crf_viterbi_accuracy: 0.9690 - val_accuracy: 0.9680
#
# Epoch 00016: val_accuracy improved from 0.96753 to 0.96804, saving model to opinion-model-0.97.hdf5
# Epoch 17/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0798 - crf_viterbi_accuracy: 0.9661 - accuracy: 0.0235 - val_loss: 0.0745 - val_crf_viterbi_accuracy: 0.9692 - val_accuracy: 0.9681
#
# Epoch 00017: val_accuracy improved from 0.96804 to 0.96807, saving model to opinion-model-0.97.hdf5
# Epoch 18/20
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.0767 - crf_viterbi_accuracy: 0.9666 - accuracy: 0.0235 - val_loss: 0.0705 - val_crf_viterbi_accuracy: 0.9700 - val_accuracy: 0.9689
#
# Epoch 00018: val_accuracy improved from 0.96807 to 0.96888, saving model to opinion-model-0.97.hdf5
# Epoch 19/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.0724 - crf_viterbi_accuracy: 0.9675 - accuracy: 0.0235 - val_loss: 0.0640 - val_crf_viterbi_accuracy: 0.9712 - val_accuracy: 0.9704
#
# Epoch 00019: val_accuracy improved from 0.96888 to 0.97042, saving model to opinion-model-0.97.hdf5
# Epoch 20/20
# 3240/3240 [==============================] - 6s 2ms/step - loss: 0.0660 - crf_viterbi_accuracy: 0.9694 - accuracy: 0.0235 - val_loss: 0.0522 - val_crf_viterbi_accuracy: 0.9761 - val_accuracy: 0.9752
#
# Epoch 00020: val_accuracy improved from 0.97042 to 0.97516, saving model to opinion-model-0.98.hdf5

# %%
def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out

# %%
! pip install seqeval
# Out:
# Collecting seqeval
#   Downloading https://files.pythonhosted.org/packages/9d/2d/233c79d5b4e5ab1dbf111242299153f3caddddbb691219f363ad55ce783d/seqeval-1.2.2.tar.gz (43kB)
#      |████████████████████████████████| 51kB 1.7MB/s eta 0:00:011
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.6/site-packages (from seqeval) (1.17.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/conda/lib/python3.6/site-packages (from seqeval) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.6/site-packages (from scikit-learn>=0.21.3->seqeval) (0.14.0)
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/lib/python3.6/site-packages (from scikit-learn>=0.21.3->seqeval) (1.3.3)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp36-none-any.whl size=16172 sha256=84836976fa2055649e3e5d781ac856be04309d7d42e464b16cd900fdc37cbae9
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
# validation
validation_pred = model.predict(X_validation, verbose=1)   
pred_labels = pred2label(validation_pred)
validation_labels = pred2label(y_validation)
# Out:
# 360/360 [==============================] - 2s 4ms/step

# %%
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
print("F1-score  validation: {:.1%}".format(f1_score(validation_labels, pred_labels)))
# Out:
# F1-score  validation: 37.5%

# %%
# testing
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
# Out:
# 400/400 [==============================] - 1s 3ms/step

# %%
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
print("F1-score  testing: {:.1%}".format(f1_score(test_labels, pred_labels)))
# Out:
# F1-score  testing: 45.0%

# %% [markdown]
# ## Model 2

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF

input = Input(shape=(maxlen,))
word_embedding_size = 150

# Embedding Layer
model2 = Embedding(input_dim=n_words, output_dim=word_embedding_size, input_length=maxlen)(input)

# BI-LSTM Layer
model2 = Bidirectional(LSTM(units=word_embedding_size, 
                           return_sequences=True, 
                           dropout=0.5, 
                           recurrent_dropout=0.5, 
                           kernel_initializer=k.initializers.he_normal()))(model2)

model2 = LSTM(units=word_embedding_size * 2, 
             return_sequences=True, 
             dropout=0.1, 
             recurrent_dropout=0.5, 
             kernel_initializer=k.initializers.he_normal())(model2)

model2 = LSTM(units=word_embedding_size * 2, 
             return_sequences=True, 
             dropout=0.1, 
             recurrent_dropout=0.5, 
             kernel_initializer=k.initializers.he_normal())(model2)

# TimeDistributed Layer
model2 = TimeDistributed(Dense(n_tags, activation="relu"))(model2)  

# CRF Layer
crf = CRF(n_tags)

out = crf(model2)  # output
model2 = Model(input, out)

# %%
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

# Compile model
model2.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])

model2.summary()

# Saving the best model only
filepath="opinion-model2-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model2.fit(X_train, np.array(y_train), batch_size=256, epochs=20, validation_split=0.1, verbose=1, callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /opt/conda/lib/python3.6/site-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        (None, 103)               0
# _________________________________________________________________
# embedding_18 (Embedding)     (None, 103, 150)          695400
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 103, 300)          361200
# _________________________________________________________________
# lstm_45 (LSTM)               (None, 103, 300)          721200
# _________________________________________________________________
# lstm_46 (LSTM)               (None, 103, 300)          721200
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 103, 3)            903
# _________________________________________________________________
# crf_17 (CRF)                 (None, 103, 3)            27
# =================================================================
# Total params: 2,499,930
# Trainable params: 2,499,930
# Non-trainable params: 0
# _________________________________________________________________
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 3240 samples, validate on 360 samples
# Epoch 1/20
# 3240/3240 [==============================] - 11s 4ms/step - loss: 0.9354 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.8921 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00001: val_accuracy improved from -inf to 0.01615, saving model to opinion-model2-0.02.hdf5
# Epoch 2/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8838 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.8728 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00002: val_accuracy did not improve from 0.01615
# Epoch 3/20
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.8646 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.8536 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00003: val_accuracy did not improve from 0.01615
# Epoch 4/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8456 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.8347 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00004: val_accuracy did not improve from 0.01615
# Epoch 5/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8268 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.8160 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00005: val_accuracy did not improve from 0.01615
# Epoch 6/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.8083 - crf_viterbi_accuracy: 0.0169 - accuracy: 0.0235 - val_loss: 0.7977 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00006: val_accuracy did not improve from 0.01615
# Epoch 7/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7901 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.7796 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00007: val_accuracy did not improve from 0.01615
# Epoch 8/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7722 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.7617 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00008: val_accuracy did not improve from 0.01615
# Epoch 9/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7545 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.7442 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00009: val_accuracy did not improve from 0.01615
# Epoch 10/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7371 - crf_viterbi_accuracy: 0.0170 - accuracy: 0.0235 - val_loss: 0.7269 - val_crf_viterbi_accuracy: 0.0156 - val_accuracy: 0.0162
#
# Epoch 00010: val_accuracy did not improve from 0.01615
# Epoch 11/20
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.7200 - crf_viterbi_accuracy: 0.1632 - accuracy: 0.0235 - val_loss: 0.7100 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00011: val_accuracy improved from 0.01615 to 0.96745, saving model to opinion-model2-0.97.hdf5
# Epoch 12/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.7032 - crf_viterbi_accuracy: 0.9659 - accuracy: 0.0235 - val_loss: 0.6933 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00012: val_accuracy did not improve from 0.96745
# Epoch 13/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.6867 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.6769 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00013: val_accuracy did not improve from 0.96745
# Epoch 14/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.6705 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.6608 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00014: val_accuracy did not improve from 0.96745
# Epoch 15/20
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.6546 - crf_viterbi_accuracy: 0.9661 - accuracy: 0.0235 - val_loss: 0.6450 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00015: val_accuracy did not improve from 0.96745
# Epoch 16/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.6390 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.6296 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00016: val_accuracy did not improve from 0.96745
# Epoch 17/20
# 3240/3240 [==============================] - 7s 2ms/step - loss: 0.6237 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.6144 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00017: val_accuracy did not improve from 0.96745
# Epoch 18/20
# 3240/3240 [==============================] - 9s 3ms/step - loss: 0.6088 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.5996 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00018: val_accuracy did not improve from 0.96745
# Epoch 19/20
# 3240/3240 [==============================] - 8s 3ms/step - loss: 0.5941 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.5850 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00019: val_accuracy did not improve from 0.96745
# Epoch 20/20
# 3240/3240 [==============================] - 8s 2ms/step - loss: 0.5798 - crf_viterbi_accuracy: 0.9660 - accuracy: 0.0235 - val_loss: 0.5708 - val_crf_viterbi_accuracy: 0.9684 - val_accuracy: 0.9674
#
# Epoch 00020: val_accuracy did not improve from 0.96745

# %%
# validation
validation_pred = model2.predict(X_validation, verbose=1)   
pred_labels = pred2label(validation_pred)
validation_labels = pred2label(y_validation)
# Out:
# 360/360 [==============================] - 2s 5ms/step

# %%
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
print("F1-score  validation: {:.1%}".format(f1_score(validation_labels, pred_labels)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5e651d0e028a> in <module>
#       1 from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
# ----> 2 print("F1-score  validation: {:.1%}".format(f1_score(validation_labels, pred_labels)))
#
# NameError: name 'validation_labels' is not defined

# %%
# testing
test_pred = model2.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
# Out:
# 400/400 [==============================] - 1s 3ms/step

# %%
print("F1-score  testing: {:.1%}".format(f1_score(test_labels, pred_labels)))
# Out:
# F1-score  testing: 0.0%
